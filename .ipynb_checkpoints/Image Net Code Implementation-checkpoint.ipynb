# %% [markdown]
# # Import Libraries or dependencies

# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds
import pathlib
import shutil
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# # Load Dataset and Vizualize

# %%
# Dataset 1- https://www.kaggle.com/datasets/umangjjw/tinyimagenet200/data(64 by 64)
# Dataset 2 - https://www.kaggle.com/datasets/ifigotin/imagenetmini-1000/data (128 by 128)

# %% [markdown]
# ## Transfer images to new file

# %%
#Image_label
     #-Images

# %%
path_image = os.path.join("tiny-imagenet-200","train")

# %%
os.path.exists(path_image)
# Out:
# True

# %%
data_dir = pathlib.Path(path_image)

# %%
list(data_dir.glob("*/*/*.JPEG"))
# Out:
# [WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_0.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_1.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_10.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_100.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_101.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_102.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_103.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_104.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_105.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_106.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_107.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_108.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_109.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_11.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_110.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_111.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_112.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_113.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_114.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_115.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_116.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_117.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_118.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_119.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_12.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_120.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_121.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_122.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_123.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_124.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_125.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_126.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_127.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_128.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_129.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_13.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_130.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_131.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_132.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_133.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_134.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_135.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_136.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_137.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_138.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_139.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_14.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_140.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_141.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_142.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_143.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_144.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_145.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_146.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_147.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_148.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_149.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_15.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_150.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_151.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_152.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_153.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_154.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_155.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_156.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_157.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_158.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_159.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_16.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_160.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_161.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_162.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_163.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_164.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_165.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_166.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_167.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_168.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_169.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_17.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_170.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_171.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_172.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_173.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_174.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_175.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_176.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_177.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_178.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_179.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_18.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_180.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_181.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_182.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_183.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_184.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_185.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_186.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_187.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_188.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_189.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_19.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_190.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_191.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_192.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_193.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_194.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_195.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_196.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_197.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_198.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_199.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_2.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_20.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_200.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_201.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_202.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_203.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_204.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_205.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_206.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_207.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_208.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_209.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_21.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_210.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_211.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_212.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_213.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_214.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_215.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_216.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_217.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_218.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_219.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_22.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_220.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_221.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_222.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_223.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_224.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_225.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_226.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_227.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_228.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_229.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_23.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_230.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_231.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_232.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_233.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_234.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_235.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_236.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_237.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_238.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_239.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_24.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_240.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_241.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_242.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_243.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_244.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_245.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_246.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_247.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_248.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_249.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_25.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_250.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_251.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_252.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_253.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_254.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_255.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_256.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_257.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_258.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_259.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_26.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_260.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_261.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_262.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_263.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_264.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_265.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_266.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_267.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_268.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_269.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_27.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_270.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_271.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_272.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_273.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_274.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_275.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_276.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_277.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_278.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_279.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_28.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_280.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_281.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_282.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_283.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_284.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_285.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_286.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_287.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_288.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_289.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_29.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_290.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_291.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_292.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_293.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_294.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_295.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_296.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_297.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_298.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_299.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_3.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_30.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_300.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_301.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_302.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_303.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_304.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_305.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_306.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_307.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_308.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_309.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_31.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_310.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_311.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_312.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_313.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_314.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_315.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_316.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_317.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_318.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_319.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_32.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_320.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_321.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_322.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_323.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_324.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_325.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_326.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_327.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_328.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_329.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_33.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_330.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_331.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_332.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_333.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_334.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_335.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_336.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_337.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_338.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_339.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_34.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_340.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_341.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_342.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_343.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_344.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_345.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_346.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_347.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_348.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_349.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_35.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_350.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_351.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_352.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_353.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_354.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_355.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01443537/images/n01443537_356.JPEG'),
# ...
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_462.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_463.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_464.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_465.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_466.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_467.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_468.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_469.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_47.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_470.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_471.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_472.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_473.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_474.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_475.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_476.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_477.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_478.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_479.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_48.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_480.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_481.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_482.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_483.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_484.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_485.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_486.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_487.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_488.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_489.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_49.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_490.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_491.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_492.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_493.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_494.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_495.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_496.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_497.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_498.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_499.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_5.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_50.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_51.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_52.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_53.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_54.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_55.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_56.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_57.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_58.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_59.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_6.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_60.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_61.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_62.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_63.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_64.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_65.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_66.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_67.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_68.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_69.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_7.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_70.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_71.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_72.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_73.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_74.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_75.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_76.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_77.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_78.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_79.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_8.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_80.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_81.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_82.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_83.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_84.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_85.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_86.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_87.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_88.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_89.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_9.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_90.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_91.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_92.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_93.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_94.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_95.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_96.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_97.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_98.JPEG'),
#  WindowsPath('C:/Users/emryz/OneDrive/Desktop/ML/computer_Vision/PaperCode/ImageNet Code Implementation/tiny-imagenet-200/train/n01629819/images/n01629819_99.JPEG'),
#  ...]

# %%
list(data_dir.glob("*/*/*.JPEG"))[200].name.split("_")
# Out:
# ['n01443537', '279.JPEG']

# %%
path_train_dir = os.path.join("train_images")

# %%
new_label_path = os.path.join(path_train_dir,"n01443537")
os.makedirs(new_label_path)

# %%
NUM_LABELS = 200
LABELS = []
PATH_OLDER_TRAIN_IMAGES = os.path.join("tiny-imagenet-200","train") 
DIR_OLDER_TRAIN_IMAGES = pathlib.Path(PATH_OLDER_TRAIN_IMAGES)
NEW_TRAIN_IMAGES_DIR = os.path.join("train_images")
IMG_HEIGHT = 64
IMG_WIDTH=64
BATCHSIZE=16

# %%
# for i in range(NUM_LABELS):
for image_path in data_dir.glob("*/*/*.JPEG"):
    image_name = image_path.name # get image name with extension
    label_name = image_name.split("_")[0] # get name without extension
    destination_path = os.path.join(NEW_TRAIN_IMAGES_DIR,label_name) # path to destination
    if label_name not in LABELS: # if new label, add to labels
        os.makedirs(destination_path) # create new destination path with label_name
        LABELS.append(label_name)
    shutil.copy(image_path,destination_path)

# %% [markdown]
# ## load Dateset

# %%
dataset = tf.keras.utils.image_dataset_from_directory(NEW_TRAIN_IMAGES_DIR,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCHSIZE)
# Out:
# Found 10000 files belonging to 20 classes.
# Using 8000 files for training.

# %%
class_name = dataset.class_names

# %%
next(dataset.take(1).as_numpy_iterator())[1]
# Out:
# array([13, 19, 18,  4, 16,  5, 17,  5,  2,  7,  7, 11,  3,  8, 19,  6])

# %% [markdown]
# ## Vizualize Dataset

# %%
plt.figure(figsize=(10, 10))
for images, labels in dataset.take(1):
    for i in range(16):
        plt.subplot(4,4,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_name[labels[i]])
        plt.axis("off")

# %%
def resize_rescale(image,label):
    image = tf.image.resize(image, [64,64])
    norm_image = image / 255
    return norm_image,label

# %%
train_ds = dataset.map(resize_rescale).cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
next(train_ds.take(1).as_numpy_iterator())[0].dtype
# Out:
# dtype('float32')

# %% [markdown]
# # Build Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Reshape, ReLU, Dropout,MaxPool2D

# %%
class Local_Response_Normalization_Layer(tf.keras.layers.Layer):
    def __init__(self,depth_radius=5, bias=1.0, alpha=1e-4, beta=0.75,**kwargs):
        super(Local_Response_Normalization_Layer, self).__init__(**kwargs)
        self.depth_radius = depth_radius
        self.bias = bias
        self.alpha = alpha
        self.beta = beta

    def call(self,inputs):
        return tf.nn.local_response_normalization(inputs,depth_radius=5, bias=1.0, alpha=1e-4, beta=0.75)

    def get_config(self):
        # Include layer parameters in configuration for saving and loading
        config = super(Local_Response_Normalization_Layer, self).get_config()
        config.update({
            'depth_radius': self.depth_radius,
            'bias': self.bias,
            'alpha': self.alpha,
            'beta': self.beta
        })
        return config

# %%
def build_alexnet_mini():
    model = Sequential()

    ## CONVULUTION LAYERS
    #block 1
    model.add(Conv2D(32,5,padding="same",input_shape=(64,64,3),activation="relu"))
    model.add(Local_Response_Normalization_Layer()) # mechanism creates lateral inhibition
    model.add(MaxPool2D(3,strides=2,padding="same"))

    #block 2
    model.add(Conv2D(64,5,padding="same",activation="relu"))
    model.add(Local_Response_Normalization_Layer())
    model.add(MaxPool2D(3,strides=2,padding="same"))

    #block 3
    model.add(Conv2D(128,3,padding="same",activation="relu"))

    #block 4
    model.add(Conv2D(128,3,padding="same",activation="relu"))

    #block 5
    model.add(Conv2D(64,3,padding="same",activation="relu"))
    model.add(MaxPool2D(3,strides=2,padding="same"))

    model.add(Flatten())

    ## FULLY CONNECTED LAYERS
    model.add(Dense(1024,activation="relu"))
    Dropout(0.5)
    model.add(Dense(512,activation="relu"))
    Dropout(0.5)
    model.add(Dense(20,activation="softmax"))
    
    return model

# %%
ALEXNET_MINI = build_alexnet_mini()
ALEXNET_MINI.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 32)        2432
#
#  local__response__normalizat  (None, 64, 64, 32)       0
#  ion__layer (Local_Response_
#  Normalization_Layer)
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        51264
#
#  local__response__normalizat  (None, 32, 32, 64)       0
#  ion__layer_1 (Local_Respons
#  e_Normalization_Layer)
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        73792
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 1024)              4195328
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 20)                10260
#
# =================================================================
# Total params: 5,079,316
# Trainable params: 5,079,316
# Non-trainable params: 0
# _________________________________________________________________

# %%
log_dir = "logs/fit/" + "ALEXNET_MINI2"
os.makedirs(log_dir)

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01,momentum=0.9,decay=0.0005)
loss = tf.keras.losses.SparseCategoricalCrossentropy()
metrics=["accuracy"]
ALEXNET_MINI.compile(optimizer=optimizer,loss=loss,metrics=metrics)

# %% [markdown]
# # Train Model

# %%
hist = ALEXNET_MINI.fit(train_ds, epochs=35,verbose=1,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/35
# 500/500 [==============================] - 9s 14ms/step - loss: 2.8891 - accuracy: 0.0990
# Epoch 2/35
# 500/500 [==============================] - 7s 14ms/step - loss: 2.6603 - accuracy: 0.1771
# Epoch 3/35
# 500/500 [==============================] - 7s 14ms/step - loss: 2.4654 - accuracy: 0.2412
# Epoch 4/35
# 500/500 [==============================] - 7s 14ms/step - loss: 2.2934 - accuracy: 0.2934
# Epoch 5/35
# 500/500 [==============================] - 7s 14ms/step - loss: 2.1061 - accuracy: 0.3503
# Epoch 6/35
# 500/500 [==============================] - 7s 14ms/step - loss: 1.8887 - accuracy: 0.4130
# Epoch 7/35
# 500/500 [==============================] - 22s 43ms/step - loss: 1.7331 - accuracy: 0.4613
# Epoch 8/35
# 500/500 [==============================] - 44s 88ms/step - loss: 1.5254 - accuracy: 0.5265
# Epoch 9/35
# 500/500 [==============================] - 44s 88ms/step - loss: 1.3158 - accuracy: 0.5907
# Epoch 10/35
# 500/500 [==============================] - 44s 88ms/step - loss: 1.1356 - accuracy: 0.6507
# Epoch 11/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.9232 - accuracy: 0.7126
# Epoch 12/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.7598 - accuracy: 0.7648
# Epoch 13/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.6101 - accuracy: 0.8101
# Epoch 14/35
# 500/500 [==============================] - 44s 87ms/step - loss: 0.4943 - accuracy: 0.8497
# Epoch 15/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.4118 - accuracy: 0.8766
# Epoch 16/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.2853 - accuracy: 0.9129
# Epoch 17/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.2366 - accuracy: 0.9302
# Epoch 18/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.2049 - accuracy: 0.9384
# Epoch 19/35
# 500/500 [==============================] - 44s 89ms/step - loss: 0.1588 - accuracy: 0.9556
# Epoch 20/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1077 - accuracy: 0.9681
# Epoch 21/35
# 500/500 [==============================] - 44s 87ms/step - loss: 0.0899 - accuracy: 0.9734
# Epoch 22/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0984 - accuracy: 0.9703
# Epoch 23/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0826 - accuracy: 0.9789
# Epoch 24/35
# 500/500 [==============================] - 44s 87ms/step - loss: 0.0592 - accuracy: 0.9810
# Epoch 25/35
# 500/500 [==============================] - 44s 87ms/step - loss: 0.0438 - accuracy: 0.9881
# Epoch 26/35
# 500/500 [==============================] - 44s 87ms/step - loss: 0.0339 - accuracy: 0.9902
# Epoch 27/35
# 500/500 [==============================] - 44s 87ms/step - loss: 0.0404 - accuracy: 0.9891
# Epoch 28/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0171 - accuracy: 0.9948
# Epoch 29/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0129 - accuracy: 0.9970
# Epoch 30/35
# 500/500 [==============================] - 44s 87ms/step - loss: 0.0072 - accuracy: 0.9983
# Epoch 31/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0041 - accuracy: 0.9992
# Epoch 32/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0030 - accuracy: 0.9994
# Epoch 33/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0023 - accuracy: 0.9995
# Epoch 34/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 35/35
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0017 - accuracy: 0.9995

# %%
data = next(train_ds.take(1).as_numpy_iterator())

# %%
plt.imshow(data[0][15])

# %%
class_name[np.argmax(ALEXNET_MINI.predict(np.expand_dims(data[0][15],axis=0)))]
# Out:
# 1/1 [==============================] - 0s 68ms/step
# 'n01855672'

# %%
plt.plot(hist.history['loss'])

# %%
plt.plot(hist.history['accuracy'])

# %%
hist.history
# Out:
# {'loss': [2.8891093730926514,
#   2.6603100299835205,
#   2.4654438495635986,
#   2.2933812141418457,
#   2.1060900688171387,
#   1.8887265920639038,
#   1.7331321239471436,
#   1.5254161357879639,
#   1.3157958984375,
#   1.13555109500885,
#   0.9232242703437805,
#   0.7597729563713074,
#   0.610149621963501,
#   0.4942511320114136,
#   0.4118238687515259,
#   0.28531473875045776,
#   0.23662687838077545,
#   0.20490123331546783,
#   0.15878519415855408,
#   0.10773233324289322,
#   0.08988059312105179,
#   0.09841620922088623,
#   0.08264985680580139,
#   0.05916322395205498,
#   0.04375821352005005,
#   0.033890578895807266,
#   0.04039178416132927,
#   0.017059138044714928,
#   0.012872510589659214,
#   0.007237215060740709,
#   0.004060670267790556,
#   0.0029715225100517273,
#   0.0022896653972566128,
#   0.0018550035310909152,
#   0.0016578605864197016],
#  'accuracy': [0.0989999994635582,
#   0.1771250069141388,
#   0.24124999344348907,
#   0.2933749854564667,
#   0.3502500057220459,
#   0.4129999876022339,
#   0.4612500071525574,
#   0.5264999866485596,
#   0.590749979019165,
#   0.6507499814033508,
#   0.7126250267028809,
#   0.7647500038146973,
#   0.8101249933242798,
#   0.8497499823570251,
#   0.8766250014305115,
#   0.9128749966621399,
#   0.9302499890327454,
#   0.9383749961853027,
#   0.9556249976158142,
#   0.9681249856948853,
#   0.9733750224113464,
#   0.9702500104904175,
#   0.9788749814033508,
#   0.9810000061988831,
#   0.9881250262260437,
#   0.9902499914169312,
#   0.9891250133514404,
#   0.9947500228881836,
#   0.996999979019165,
#   0.9982500076293945,
#   0.9992499947547913,
#   0.9993749856948853,
#   0.9994999766349792,
#   0.9994999766349792,
#   0.9994999766349792]}

# %% [markdown]
# ## Save Model and Laod Model

# %% [markdown]
# ## Old Save

# %%
ALEXNET_MINI.save("ALEX_NET_MINI.h5")

# %%
loaded_model = tf.keras.models.load_model("ALEX_NET_MINI2.h5", custom_objects={'Local_Response_Normalization_Layer': Local_Response_Normalization_Layer})

# %% [markdown]
# ## New Save

# %%
ALEXNET_MINI.save("ALEX_NET_MINI2.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ALEXNET_MINI.save("ALEX_NET_MINI2.h5")
#
# NameError: name 'ALEXNET_MINI' is not defined

# %%
model = loaded_model

# %% [markdown]
# # Inference

# %% [markdown]
# # Single Prediction

# %%
class_value = []
with open("words.txt","r") as f:
    class_value = f.readlines()

# %%
class_value
# Out:
# ['n00001740\tentity\n',
#  'n00001930\tphysical entity\n',
#  'n00002137\tabstraction, abstract entity\n',
#  'n00002452\tthing\n',
#  'n00002684\tobject, physical object\n',
#  'n00003553\twhole, unit\n',
#  'n00003993\tcongener\n',
#  'n00004258\tliving thing, animate thing\n',
#  'n00004475\torganism, being\n',
#  'n00005787\tbenthos\n',
#  'n00005930\tdwarf\n',
#  'n00006024\theterotroph\n',
#  'n00006150\tparent\n',
#  'n00006269\tlife\n',
#  'n00006400\tbiont\n',
#  'n00006484\tcell\n',
#  'n00007347\tcausal agent, cause, causal agency\n',
#  'n00007846\tperson, individual, someone, somebody, mortal, soul\n',
#  'n00015388\tanimal, animate being, beast, brute, creature, fauna\n',
#  'n00017222\tplant, flora, plant life\n',
#  'n00019046\tnative\n',
#  'n00019128\tnatural object\n',
#  'n00019613\tsubstance\n',
#  'n00020090\tsubstance\n',
#  'n00020827\tmatter\n',
#  'n00021265\tfood, nutrient\n',
#  'n00021734\tnutrient\n',
#  'n00021939\tartifact, artefact\n',
#  'n00022903\tarticle\n',
#  'n00023100\tpsychological feature\n',
#  'n00023271\tcognition, knowledge, noesis\n',
#  'n00023773\tmotivation, motive, need\n',
#  'n00024264\tattribute\n',
#  'n00024720\tstate\n',
#  'n00026192\tfeeling\n',
#  'n00027167\tlocation\n',
#  'n00027807\tshape, form\n',
#  'n00028270\ttime\n',
#  'n00028651\tspace, infinite\n',
#  'n00029007\tabsolute space\n',
#  'n00029114\tphase space\n',
#  'n00029378\tevent\n',
#  'n00029677\tprocess, physical process\n',
#  'n00030358\tact, deed, human action, human activity\n',
#  'n00031264\tgroup, grouping\n',
#  'n00031921\trelation\n',
#  'n00032613\tpossession\n',
#  'n00032823\tsocial relation\n',
#  'n00033020\tcommunication\n',
#  'n00033615\tmeasure, quantity, amount\n',
#  'n00034213\tphenomenon\n',
#  'n00034479\tthing\n',
#  'n00034574\tkindness, benignity\n',
#  'n00034777\tabdominoplasty, tummy tuck\n',
#  'n00034939\tabort\n',
#  'n00035189\taccomplishment, achievement\n',
#  'n00035697\tagon\n',
#  'n00035891\talienation\n',
#  'n00036061\tapplication\n',
#  'n00036299\tbeachhead, foothold\n',
#  'n00036580\tcakewalk\n',
#  'n00036762\tfeat, effort, exploit\n',
#  'n00037006\tmasterpiece\n',
#  'n00037090\tmasterstroke\n',
#  'n00037200\tcredit\n',
#  'n00037396\taction\n',
#  'n00038175\tres gestae\n',
#  'n00038262\tcourse, course of action\n',
#  'n00038573\tblind alley\n',
#  'n00038863\tcollision course\n',
#  'n00039021\tinteraction\n',
#  'n00039211\tinterplay\n',
#  'n00039297\tcontact\n',
#  'n00039545\tbrush\n',
#  'n00039740\teye contact\n',
#  'n00039916\tfetch\n',
#  'n00039990\tplacement\n',
#  'n00040152\tinterchange, reciprocation, give-and-take\n',
#  'n00040420\treciprocity\n',
#  'n00040545\tcross-fertilization, cross-fertilisation\n',
#  'n00040804\tdealings, traffic\n',
#  'n00040962\trelation\n',
#  'n00041188\tplaying\n',
#  'n00041468\tplay, swordplay\n',
#  'n00041614\tboondoggle\n',
#  'n00041740\tbowling\n',
#  'n00041899\tacquiring, getting\n',
#  'n00042311\tcausing, causation\n',
#  'n00042541\tdelivery, obstetrical delivery\n',
#  'n00042757\tdeparture, going, going away, leaving\n',
#  'n00043116\tderring-do\n',
#  'n00043195\tdiscovery, find, uncovering\n',
#  'n00043609\tdisposal, disposition\n',
#  'n00043902\thit\n',
#  'n00044150\timplementation, effectuation\n',
#  'n00044455\tegress, egression, emergence\n',
#  'n00044673\tequalization, equalisation, leveling\n',
#  'n00044900\texhumation, disinterment, digging up\n',
#  'n00045114\tmitzvah, mitsvah\n',
#  'n00045250\tpropulsion, actuation\n',
#  'n00045646\trally, rallying\n',
#  'n00045907\trecovery, retrieval\n',
#  'n00046177\trunning away\n',
#  'n00046344\tstunt\n',
#  'n00046522\ttouch, touching\n',
#  'n00047018\ttour de force\n',
#  'n00047106\tperformance\n',
#  'n00047356\toverachievement\n',
#  'n00047550\tunderachievement\n',
#  'n00047745\trecord, track record\n',
#  'n00047941\tfait accompli, accomplished fact\n',
#  'n00048051\tgoing, sledding\n',
#  'n00048225\tarrival, reaching\n',
#  'n00048374\tarrival\n',
#  'n00048656\tattainment\n',
#  'n00048828\tadvent, coming\n',
#  'n00049003\tentrance, entering, entry, ingress, incoming\n',
#  'n00049344\tincursion\n',
#  'n00049530\tintrusion\n',
#  'n00049636\tirruption\n',
#  'n00049789\tentree\n',
#  'n00049909\tentail\n',
#  'n00050037\tregistration, enrollment, enrolment\n',
#  'n00050195\tappearance\n',
#  'n00050484\tapparition\n',
#  'n00050693\temergence, emersion\n',
#  'n00050887\treappearance, return\n',
#  'n00051077\tcomeback\n',
#  'n00051192\treturn, homecoming\n',
#  'n00051385\trepatriation\n',
#  'n00051525\tpenetration\n',
#  'n00051712\tinterpenetration, permeation\n',
#  'n00051897\tmarket penetration\n',
#  'n00052052\tanchorage\n',
#  'n00052146\tdocking, moorage, dockage, tying up\n',
#  'n00052334\tlanding\n',
#  'n00052500\tlanding\n',
#  'n00052791\tforced landing, emergency landing\n',
#  'n00053020\tbreaking away\n',
#  'n00053097\tfarewell, leave, leave-taking, parting\n',
#  'n00053405\tFrench leave\n',
#  'n00053525\tvalediction\n',
#  'n00053609\tdisappearance, disappearing\n',
#  'n00053806\tvanishing\n',
#  'n00053913\twithdrawal\n',
#  'n00054328\teffacement, self-effacement\n',
#  'n00054483\tretreat\n',
#  'n00054652\tretirement, retreat\n',
#  'n00054821\tevacuation\n',
#  'n00055038\tmedical evacuation, medevac, medivac\n',
#  'n00055227\tdecampment\n',
#  'n00055315\tdesertion, abandonment, defection\n',
#  'n00055633\tabscondment, decampment\n',
#  'n00055793\tabsence without leave, unauthorized absence\n',
#  'n00055932\tdeviationism\n',
#  'n00056087\temigration, out-migration, expatriation\n',
#  'n00056311\timmigration, in-migration\n',
#  'n00056551\taliyah\n',
#  'n00056688\tpullback\n',
#  'n00056912\tretreat\n',
#  'n00057162\tstanddown, stand-down\n',
#  'n00057306\tdisengagement, fallback, pullout\n',
#  'n00057486\treceding, recession\n',
#  'n00057657\tsailing\n',
#  'n00057748\tamphibious landing\n',
#  'n00058002\tdebarkation, disembarkation, disembarkment\n',
#  'n00058247\tgoing ashore\n',
#  'n00058337\tboarding, embarkation, embarkment\n',
#  'n00058519\texit\n',
#  'n00058608\telopement\n',
#  'n00058743\tescape, flight\n',
#  'n00059127\tevasion\n',
#  'n00059376\tslip, elusion, eluding\n',
#  'n00059552\tmaneuver, manoeuvre, evasive action\n',
#  'n00059728\tclinch\n',
#  'n00059895\tdodge\n',
#  'n00059989\tbreak, breakout, jailbreak, gaolbreak, prisonbreak, prison-breaking\n',
#  'n00060201\tgetaway, lam\n',
#  'n00060414\texodus, hegira, hejira\n',
#  'n00060548\tHegira, Hejira\n',
#  'n00060747\tskedaddle\n',
#  'n00060817\tUnderground Railroad, Underground Railway\n',
#  'n00061014\tclose call, close shave, squeak, squeaker, narrow escape\n',
#  'n00061171\tsurfacing\n',
#  'n00061290\tdispatch, despatch, shipment\n',
#  'n00061453\treshipment\n',
#  'n00061598\tconsummation\n',
#  'n00061792\tconsummation\n',
#  'n00061917\trealization, realisation, fruition\n',
#  'n00062133\torgasm, climax, sexual climax, coming\n',
#  'n00062331\tmale orgasm\n',
#  'n00062451\tfulfillment, fulfilment\n',
#  'n00062671\tself-fulfillment, self-realization, self-realisation\n',
#  'n00062806\tattainment\n',
#  'n00063014\trecord\n',
#  'n00063310\ttrack record\n',
#  'n00063559\tworld record\n',
#  'n00063652\tsuccess\n',
#  'n00064018\twinning\n',
#  'n00064151\tblockbuster, megahit, smash hit\n',
#  'n00064370\tsleeper\n',
#  'n00064504\thit, smash, smasher, strike, bang\n',
#  "n00064789\tbell ringer, bull's eye, mark, home run\n",
#  'n00065098\tennoblement\n',
#  'n00065216\tconquest\n',
#  'n00065336\tcoup\n',
#  'n00065418\tflying colors, flying colours\n',
#  'n00065575\tpassing, pass, qualifying\n',
#  'n00065855\tcredit, course credit\n',
#  'n00066075\tsemester hour, credit hour\n',
#  'n00066216\tnonaccomplishment, nonachievement\n',
#  'n00066397\tfailure\n',
#  'n00066636\tfailure\n',
#  'n00066901\tfailing, flunk\n',
#  'n00067153\tnaught\n',
#  'n00067254\tcut\n',
#  'n00067397\tdefault\n',
#  'n00067526\tloss\n',
#  'n00067707\tcapitulation, fall, surrender\n',
#  'n00067990\tfrustration, thwarting, foiling\n',
#  'n00068170\toverturn, upset\n',
#  'n00068333\tbacksliding, lapse, lapsing, relapse, relapsing, reversion, reverting\n',
#  'n00068617\trecidivism\n',
#  'n00068755\tdisappointment, dashing hopes\n',
#  'n00068901\tbreach\n',
#  'n00069060\tcopout\n',
#  'n00069173\tbreach of contract\n',
#  'n00069444\tanticipatory breach, constructive breach\n',
#  'n00069604\tbreach of duty\n',
#  'n00069685\tbreach of the covenant of warranty\n',
#  'n00069815\tbreach of promise\n',
#  'n00069918\tbreach of trust\n',
#  'n00070077\tbreach of trust with fraudulent intent\n',
#  'n00070215\tbreach of warranty\n',
#  'n00070363\tleaning\n',
#  'n00070462\tmaterial breach\n',
#  'n00070641\tmotivation, motivating\n',
#  'n00070807\tpartial breach\n',
#  'n00070965\tmistake, error, fault\n',
#  'n00071546\tdouble fault\n',
#  'n00071700\tfootfault\n',
#  'n00071864\tbobble\n',
#  'n00072068\terror, misplay\n',
#  'n00072261\tblot, smear, smirch, spot, stain\n',
#  'n00072473\tconfusion, mix-up\n',
#  'n00072691\tincursion\n',
#  'n00072808\tmiscalculation, misreckoning, misestimation\n',
#  'n00073032\tbackfire, boomerang\n',
#  'n00073177\trounding, rounding error\n',
#  'n00073525\ttruncation error\n',
#  'n00073713\tdistortion\n',
#  'n00073828\tslip, slip-up, miscue, parapraxis\n',
#  'n00074092\tFreudian slip\n',
#  'n00074324\toffside\n',
#  'n00074524\toversight, lapse\n',
#  'n00074624\tomission, skip\n',
#  'n00074790\tblunder, blooper, bloomer, bungle, pratfall, foul-up, fuckup, flub, botch, boner, boo-boo\n',
#  'n00075283\tsnafu\n',
#  'n00075471\tspectacle\n',
#  'n00075618\tballup, balls-up, cockup, mess-up\n',
#  'n00075790\tbull\n',
#  'n00075912\tfumble, muff\n',
#  'n00076072\tfluff\n',
#  'n00076196\tfaux pas, gaffe, solecism, slip, gaucherie\n',
#  'n00076323\thowler\n',
#  'n00076393\tclanger\n',
#  'n00076563\ttrip, trip-up, stumble, misstep\n',
#  'n00076884\tspill, tumble, fall\n',
#  'n00077169\tpratfall\n',
#  'n00077249\twipeout\n',
#  'n00077419\tacquisition\n',
#  'n00077856\tobtainment, obtention\n',
#  'n00077981\tcatching, contracting\n',
#  'n00078217\tincurring\n',
#  'n00078393\tmoneymaking\n',
#  'n00078536\tannexation\n',
#  'n00078821\tpork-barreling\n',
#  'n00079018\tpurchase\n',
#  'n00079212\tredemption, repurchase, buyback\n',
#  'n00079398\ttrading\n',
#  'n00079603\tbond trading, bond-trading activity\n',
#  'n00079752\tprogram trading\n',
#  'n00079908\tshort sale, short selling\n',
#  'n00080096\tshort covering\n',
#  'n00080242\tinsider trading\n',
#  'n00080474\tnaked option\n',
#  'n00080619\tcovered option\n',
#  'n00080743\tcall option, call\n',
#  'n00080968\tput option, put\n',
#  'n00081174\tstraddle\n',
#  'n00081395\tincentive option, incentive stock option\n',
#  'n00081572\tbuying, purchasing\n',
#  'n00081836\tshopping\n',
#  'n00082081\tmarketing\n',
#  'n00082223\tmail-order buying, catalog buying\n',
#  'n00082347\tviatication, viaticus\n',
#  'n00082525\tacceptance\n',
#  'n00082754\tsuccession, taking over\n',
#  'n00082870\tassumption, laying claim\n',
#  'n00083260\tassumption\n',
#  'n00083448\tposition\n',
#  'n00083585\tinheritance, heritage\n',
#  'n00083729\tprocurement, procurance, procural\n',
#  'n00083975\tappropriation\n',
#  'n00084371\tborrowing, adoption\n',
#  'n00084642\tnaturalization, naturalisation\n',
#  'n00084895\tmisappropriation\n',
#  'n00085041\tpreemption, pre-emption\n',
#  'n00085219\tseizure\n',
#  'n00085432\tusurpation\n',
#  'n00085678\tconfiscation, arrogation\n',
#  'n00085829\tdistress, distraint\n',
#  'n00086140\texpropriation\n',
#  'n00086297\timpoundment, impounding, internment, poundage\n',
#  'n00086547\tdrug bust, drugs bust\n',
#  'n00086654\timpress, impressment\n',
#  'n00086809\toccupation, occupancy, moving in\n',
#  'n00087073\tpreoccupancy, preoccupation\n',
#  'n00087218\tsequestration, requisition\n',
#  'n00087423\tgrant, subsidization, subsidisation\n',
#  'n00087663\taward, awarding\n',
#  'n00087849\taddiction\n',
#  'n00088154\tblock grant\n',
#  'n00088367\tgrant-in-aid\n',
#  'n00088481\tcapture, gaining control, seizure\n',
#  'n00088725\tapprehension, arrest, catch, collar, pinch, taking into custody\n',
#  'n00089027\tconquest, conquering, subjection, subjugation\n',
#  'n00089234\tenslavement\n',
#  'n00089351\trestitution, return, restoration, regaining\n',
#  'n00089657\tclawback\n',
#  'n00089891\trepossession\n',
#  'n00090076\tforeclosure\n',
#  'n00090253\treception, receipt\n',
#  'n00090393\tappointment\n',
#  'n00090610\tcomb-out\n',
#  'n00090779\tgiving\n',
#  'n00091013\tabandonment\n',
#  'n00091234\tdiscard, throwing away\n',
#  'n00091404\tstaging\n',
#  'n00091503\tdiscard\n',
#  'n00091670\tmine disposal\n',
#  'n00091779\tminesweeping\n',
#  'n00091893\tsewage disposal\n',
#  'n00091977\tbait and switch\n',
#  'n00092212\tprivate treaty\n',
#  'n00092366\tauction, auction sale, vendue\n',
#  'n00092663\tbootlegging\n',
#  'n00092847\tbootlegging\n',
#  'n00093006\tcapitalization, capitalisation\n',
#  'n00093127\tovercapitalization, overcapitalisation\n',
#  'n00093354\treclamation\n',
#  'n00093483\trescue, deliverance, delivery, saving\n',
#  'n00093874\tlifesaving\n',
#  'n00094001\tredemption, salvation\n',
#  'n00094240\tabsolution, remission, remittal, remission of sin\n',
#  'n00094500\tindulgence\n',
#  'n00094788\tconversion, rebirth, spiritual rebirth\n',
#  'n00094954\tproselytism\n',
#  'n00095121\texpiation, atonement, propitiation\n',
#  'n00095329\treparation, amends\n',
#  'n00095502\tliberation, release, freeing\n',
#  'n00095873\tjail delivery\n',
#  'n00095971\treclamation, reformation\n',
#  'n00096211\tsalvage\n',
#  'n00096343\tsalvage\n',
#  'n00096513\tsalvation\n',
#  'n00096720\tsearch and rescue mission\n',
#  'n00096851\transom\n',
#  'n00096969\trecapture, retaking\n',
#  'n00097122\trecapture\n',
#  'n00097244\tinvocation\n',
#  'n00097348\tinstrumentation\n',
#  'n00097504\tperformance, execution, carrying out, carrying into action\n',
#  'n00097923\tspecific performance\n',
#  'n00098051\tlinguistic performance\n',
#  'n00098385\tmechanism, mechanics\n',
#  'n00098625\tservice\n',
#  'n00098822\tcurb service\n',
#  'n00098939\tself-service\n',
#  'n00099061\tvalet parking\n',
#  'n00099267\tdramatic production, dramatic performance\n',
#  'n00099439\tencore\n',
#  'n00099588\textemporization, extemporisation, improvisation\n',
#  'n00099799\tjuggle, juggling\n',
#  'n00099951\tmagic trick, conjuring trick, trick, magic, legerdemain, conjuration, thaumaturgy, illusion, deception\n',
#  'n00100253\tmusical performance\n',
#  'n00100437\tone-night stand\n',
#  'n00100543\trendition, rendering, interpretation\n',
#  'n00100889\treinterpretation\n',
#  'n00101003\tspin\n',
#  'n00101191\tplaying\n',
#  'n00101410\tbowing\n',
#  'n00101570\tspiccato, spiccato bowing\n',
#  'n00101708\tpiping\n',
#  'n00101809\tstopping\n',
#  'n00102039\tdouble stopping\n',
#  'n00102162\ttransposition\n',
#  'n00102374\tjam session\n',
#  'n00102457\tautomation, mechanization, mechanisation\n',
#  'n00102779\tcomputerization, cybernation\n',
#  'n00102927\tmotorization, motorisation\n',
#  'n00103140\tlaunching, launch\n',
#  'n00103291\tlaunching\n',
#  'n00103419\trocket firing, rocket launching\n',
#  'n00103590\tblastoff, shot\n',
#  'n00103737\tmoon shot\n',
#  'n00103834\tdrive, thrust, driving force\n',
#  'n00104088\tfirewall\n',
#  'n00104249\timpulse, impulsion, impetus\n',
#  'n00104409\troll, bowl\n',
#  'n00104539\tthrow\n',
#  'n00104976\tbowling\n',
#  'n00105164\tfling\n',
#  'n00105271\theave, heaving\n',
#  'n00105479\thurl, cast\n',
#  'n00105624\tleaner\n',
#  'n00105820\tpass, toss, flip\n',
#  'n00106104\tpitch\n',
#  'n00106272\tpitch, delivery\n',
#  'n00106726\tringer\n',
#  'n00106888\tshy\n',
#  'n00107016\tslinging\n',
#  'n00107137\tthrow-in\n',
#  'n00107279\tbalk\n',
#  'n00107400\tball\n',
#  'n00107551\tbeanball, beaner\n',
#  'n00107684\tchange-up, change-of-pace, change-of-pace ball, off-speed pitch\n',
#  'n00107875\tcurve, curve ball, breaking ball, bender\n',
#  'n00108081\tduster\n',
#  'n00108181\tfastball, heater, smoke, hummer, bullet\n',
#  'n00108427\tknuckleball, knuckler\n',
#  'n00108545\toverhand pitch\n',
#  'n00108665\tpassed ball\n',
#  'n00108818\tscrewball\n',
#  'n00108965\tsinker\n',
#  'n00109081\tslider\n',
#  'n00109227\tspitball, spitter\n',
#  'n00109414\tstrike\n',
#  'n00109771\tsubmarine ball, submarine pitch\n',
#  'n00109892\twild pitch\n',
#  'n00110057\tbasketball shot\n',
#  'n00110415\tbank shot\n',
#  'n00110554\tdunk, dunk shot, stuff shot\n',
#  'n00110745\tslam dunk\n',
#  'n00110834\tfinger-roll\n',
#  'n00110964\tfoul shot, free throw, penalty free throw, charity toss, charity throw, charity shot\n',
#  'n00111222\tone-and-one\n',
#  'n00111358\thook shot, hook\n',
#  'n00111503\tjumper, jump shot\n',
#  'n00111660\tlay-up, layup\n',
#  'n00111839\tpivot shot\n',
#  'n00111962\tset shot\n',
#  'n00112072\tscoop shot\n',
#  'n00112185\ttip in\n',
#  'n00112312\tpush, pushing\n',
#  'n00112674\tdepression\n',
#  'n00112828\tclick, mouse click\n',
#  'n00112997\tnudge, jog\n',
#  'n00113113\tpress, pressure, pressing\n',
#  'n00113532\timpression\n',
#  'n00113726\tshove\n',
#  'n00113954\tbundling\n',
#  'n00114095\tjostle, jostling\n',
#  'n00114298\telbowing\n',
#  'n00114431\tpull, pulling\n',
#  'n00114871\tdrag\n',
#  'n00115036\tdraw, haul, haulage\n',
#  'n00115292\ttow, towage\n',
#  'n00115500\ttug, jerk\n',
#  'n00115667\tdraft, draught, drawing\n',
#  'n00115803\textirpation, excision, deracination\n',
#  'n00116008\tpluck\n',
#  'n00116122\ttraction\n',
#  'n00116376\tlift, raise, heave\n',
#  'n00116687\texpulsion, projection, ejection, forcing out\n',
#  'n00116989\tdefenestration\n',
#  'n00117124\taccommodation reflex\n',
#  'n00117267\tBabinski, Babinski reflex, Babinski sign\n',
#  'n00117578\tbelch, belching, burp, burping, eructation\n',
#  'n00117810\tbelching\n',
#  'n00117959\tblink, eye blink, blinking, wink, winking, nictitation, nictation\n',
#  'n00118268\tblush, flush\n',
#  'n00118445\tcoughing up\n',
#  'n00118552\tspit, spitting, expectoration\n',
#  'n00118733\tvomit, vomiting, emesis, regurgitation, disgorgement, puking\n',
#  'n00119079\trumination\n',
#  'n00119210\thematemesis, haematemesis\n',
#  'n00119297\thyperemesis\n',
#  'n00119402\thyperemesis gravidarum\n',
#  'n00119568\tjump, jumping\n',
#  'n00119893\theader\n',
#  'n00120010\thop\n',
#  'n00120202\tleap, leaping, spring, saltation, bound, bounce\n',
#  'n00120515\tvault, hurdle\n',
#  'n00120647\tjumping up and down\n',
#  'n00120804\tlob\n',
#  'n00120943\tcentering, snap\n',
#  'n00121166\tsending\n',
#  'n00121366\ttransmission, transmittal, transmitting\n',
#  'n00121645\tforwarding\n',
#  'n00121904\treferral\n',
#  'n00122106\tremission, remitment, remit\n',
#  'n00122338\tmailing, posting\n',
#  'n00122530\twheeling, rolling\n',
#  'n00122661\tshooting, shot\n',
#  'n00122954\tshoot\n',
#  'n00123143\tcountershot\n',
#  'n00123234\tdischarge, firing, firing off\n',
#  'n00123430\tgun\n',
#  'n00123652\tfire control\n',
#  'n00123783\tgunfire, gunshot\n',
#  'n00124008\tenfilade, enfilade fire\n',
#  'n00124151\tsnipe\n',
#  'n00124256\theadshot\n',
#  'n00124342\tskeet, skeet shooting, trapshooting\n',
#  'n00124536\tshellfire\n',
#  'n00124617\tgunfight, gunplay, shootout\n',
#  'n00124766\tpotshot\n',
#  'n00124880\tcontact, physical contact\n',
#  'n00125126\trub, wipe\n',
#  'n00125315\tscuff\n',
#  'n00125436\ttap, pat, dab\n',
#  'n00125629\thit, hitting, striking\n',
#  'n00126100\tcontusion\n',
#  'n00126236\tcrash, smash\n',
#  'n00126447\timpingement, impaction\n',
#  'n00126584\tbatting\n',
#  'n00126721\tfielding\n',
#  'n00126886\tcatching\n',
#  'n00127021\tgolfing\n',
#  'n00127151\tpitching\n',
#  'n00127286\tbase on balls, walk, pass\n',
#  'n00127531\tbest\n',
#  'n00127672\tworst\n',
#  'n00127866\tfair ball\n',
#  'n00128091\tfoul ball\n',
#  'n00128324\tsnick\n',
#  'n00128477\tbunt\n',
#  'n00128638\tfly, fly ball\n',
#  'n00128867\tblast\n',
#  'n00128976\tpop fly, pop-fly, pop-up\n',
#  'n00129089\tgrounder, ground ball, groundball, hopper\n',
#  'n00129317\tchop, chopper\n',
#  'n00129435\troller\n',
#  'n00129527\tout\n',
#  'n00129743\tforce out, force-out, force play, force\n',
#  'n00130093\tputout\n',
#  'n00130347\tstrikeout\n',
#  'n00130512\twhiff\n',
#  "n00130673\tfielder's choice\n",
#  'n00130846\tsacrifice\n',
#  'n00130987\tsacrifice fly\n',
#  'n00131090\tbase hit, safety\n',
#  'n00131347\tdaisy cutter\n',
#  'n00131485\theader\n',
#  'n00131608\tliner, line drive\n',
#  'n00131791\tscorcher, screamer\n',
#  'n00131877\tline-drive single, line single\n',
#  'n00131991\tline-drive double, line double\n',
#  'n00132105\tline-drive triple, line triple\n',
#  'n00132219\tplunk, plunker\n',
#  'n00132355\thomer, home run\n',
#  'n00132497\tsolo homer, solo blast\n',
#  'n00132601\tsingle, bingle\n',
#  'n00132756\tdouble, two-base hit, two-bagger, two-baser\n',
#  'n00132982\ttriple, three-base hit, three-bagger\n',
#  'n00133160\tbackhander\n',
#  'n00133234\tclip\n',
#  'n00133338\tknock, belt, rap, whack, whang\n',
#  'n00133567\tthwack\n',
#  'n00133668\tsmack, smacking, slap\n',
#  'n00133875\tsmacker\n',
#  'n00133981\tknockdown\n',
#  'n00134099\tknockout, KO, kayo\n',
#  'n00134246\ttechnical knockout, TKO\n',
#  'n00134391\tswat\n',
#  'n00134472\tspank\n',
#  'n00134574\twhip, lash, whiplash\n',
#  'n00134780\tpunch, clout, poke, lick, biff, slug\n',
#  'n00135148\tbox\n',
#  'n00135311\tdig, jab\n',
#  'n00135504\tcounterpunch, parry, counter\n',
#  'n00135637\thaymaker, knockout punch, KO punch, Sunday punch\n',
#  'n00135799\thook\n',
#  'n00135952\tjab\n',
#  'n00136048\trabbit punch\n',
#  'n00136152\tsucker punch\n',
#  'n00136230\troundhouse\n',
#  'n00136329\tkick, boot, kicking\n',
#  'n00136691\tgoal-kick\n',
#  'n00136876\tgoal-kick\n',
#  'n00136984\tpunt, punting\n',
#  'n00137279\tplace kick, place-kicking\n',
#  'n00137534\tfree kick\n',
#  'n00137709\tcorner kick\n',
#  'n00137877\tdropkick\n',
#  'n00138078\tkiss\n',
#  'n00138221\tkiss, buss, osculation\n',
#  'n00138441\tlaying on\n',
#  'n00138599\tsmack, smooch\n',
#  'n00138734\tsmacker\n',
#  'n00138799\tsoul kiss, deep kiss, French kiss\n',
#  'n00138956\tcatch, grab, snatch, snap\n',
#  'n00139544\tfair catch\n',
#  'n00139758\tinterception\n',
#  'n00139919\treception\n',
#  'n00140112\trebound\n',
#  'n00140264\tshoestring catch\n',
#  'n00140393\tmesh, meshing, interlock, interlocking\n',
#  'n00140652\thandling, manipulation\n',
#  'n00140900\tfingering\n',
#  'n00141027\tgrope\n',
#  'n00141176\taudit\n',
#  'n00141396\tautopsy, necropsy, postmortem, post-mortem, PM, postmortem examination, post-mortem examination\n',
#  'n00141669\tcheck-in\n',
#  'n00141806\tcheck, checkout, check-out procedure\n',
#  'n00142140\tspot check\n',
#  'n00142361\tcheckup, medical checkup, medical examination, medical exam, medical, health check\n',
#  'n00142665\tcomparison, comparing\n',
#  'n00143057\tfine-tooth comb, fine-toothed comb\n',
#  'n00143251\tfollow-up, followup, reexamination, review\n',
#  'n00143536\tgoing-over\n',
#  'n00143626\tonce-over, look-over\n',
#  'n00143763\tophthalmoscopy\n',
#  'n00143885\tpalpation, tactual exploration\n',
#  'n00144182\tballottement\n',
#  'n00144445\ttickle, tickling, titillation\n',
#  'n00144632\tstroke, stroking\n',
#  'n00144778\tcaress\n',
#  'n00145024\ttag\n',
#  'n00145218\tjoining, connection, connexion\n',
#  'n00145779\thit\n',
#  'n00145929\tinterconnection\n',
#  'n00146111\tintersection\n',
#  'n00146277\tapproximation, bringing close together\n',
#  'n00146443\tconcatenation\n',
#  'n00146572\tconvergence, converging, convergency\n',
#  'n00146856\tmerging, meeting, coming together\n',
#  'n00147091\tconcourse, confluence\n',
#  'n00147187\tencounter, coming upon\n',
#  'n00147314\tarticulation\n',
#  'n00147454\tjunction, adjunction\n',
#  'n00147595\tfastening, attachment\n',
#  'n00147862\tloosening, laxation\n',
#  'n00148057\ttightening\n',
#  'n00148242\tligation\n',
#  'n00148446\ttubal ligation\n',
#  'n00148653\tbonding, soldering\n',
#  'n00148762\tdoweling\n',
#  'n00148836\tgrounding, earthing\n',
#  'n00148978\tlinkage\n',
#  'n00149084\ttying, ligature\n',
#  'n00149262\tuntying, undoing, unfastening\n',
#  'n00149508\twelding\n',
#  'n00149699\tbutt welding, butt-welding\n',
#  'n00149895\tspot welding, spot-welding\n',
#  'n00150097\tflare\n',
#  'n00150228\tTexas leaguer\n',
#  'n00150379\tflash welding, flash butt welding\n',
#  'n00150591\tlick, lap\n',
#  'n00150762\tgrazing, shaving, skimming\n',
#  'n00150932\ttracing\n',
#  'n00151087\tdetection, catching, espial, spying, spotting\n',
#  'n00151314\tself-discovery\n',
#  'n00151409\tbreakthrough\n',
#  'n00151497\tdetermination, finding\n',
#  'n00151914\trediscovery\n',
#  'n00152018\tdesignation, identification\n',
#  'n00152230\tBertillon system\n',
#  'n00152338\tfingerprinting\n',
#  'n00152519\tgenetic profiling, genetic fingerprinting\n',
#  'n00152727\tdiagnosis, diagnosing\n',
#  'n00152990\tblood typing\n',
#  'n00153105\tmedical diagnosis\n',
#  'n00153288\tprenatal diagnosis\n',
#  'n00153499\tdifferential diagnosis\n',
#  'n00153665\tprognosis, prospect, medical prognosis\n',
#  'n00153809\tresolution, solving\n',
#  'n00153961\tvalidation, proof, substantiation\n',
#  'n00154233\tauthentication, certification\n',
#  'n00154433\tdocumentation, support\n',
#  'n00154689\tmonetization, monetisation\n',
#  'n00154894\tprobate\n',
#  'n00155085\tdemonetization, demonetisation\n',
#  'n00155298\tfalsification, falsifying, disproof, refutation, refutal\n',
#  'n00155487\tlocalization, localisation, location, locating, fix\n',
#  'n00155797\techolocation, echo sounding\n',
#  'n00155970\tpredetermination\n',
#  'n00156119\trectification\n',
#  'n00156293\tredetermination\n',
#  'n00156390\ttrigger, induction, initiation\n',
#  'n00156625\tfomentation, instigation\n',
#  'n00156812\tcompulsion, coercion\n',
#  'n00157081\tinfluence\n',
#  'n00157318\tcross-pollination\n',
#  'n00157463\texposure\n',
#  'n00157687\toverexposure\n',
#  'n00157877\tunderexposure\n',
#  'n00157957\timpingement, encroachment, impact\n',
#  'n00158185\tmanipulation, use\n',
#  'n00158443\tmind game\n',
#  'n00158805\tautosuggestion, auto-suggestion, self-suggestion\n',
#  'n00158996\thypnotism, mesmerism, suggestion\n',
#  'n00159177\tinducement, inducing\n',
#  'n00159396\tcorruption\n',
#  'n00159620\tenticement, temptation\n',
#  'n00159899\tblandishment, wheedling\n',
#  'n00160073\tingratiation, insinuation\n',
#  'n00160297\tleading astray, leading off\n',
#  'n00160415\tseduction\n',
#  'n00160532\tseduction, conquest\n',
#  'n00160688\tsexual conquest, score\n',
#  'n00160922\tcuckoldry\n',
#  'n00161044\tsolicitation, allurement\n',
#  'n00161243\tchoice, selection, option, pick\n',
#  'n00161603\tcasting\n',
#  'n00161739\tcoloration, colouration\n',
#  'n00161888\tsampling\n',
#  'n00162055\trandom sampling\n',
#  'n00162236\tlucky dip\n',
#  'n00162417\tstratified sampling, representative sampling, proportional sampling\n',
#  'n00162632\tdecision, determination, conclusion\n',
#  'n00163047\tvolition, willing\n',
#  'n00163233\tintention\n',
#  'n00163406\tabout-face, volte-face, reversal, policy change\n',
#  'n00163630\tadulteration\n',
#  'n00163779\tappointment, assignment, designation, naming\n',
#  'n00164152\tnomination\n',
#  'n00164345\tassignment, assigning\n',
#  'n00164579\tallocation, storage allocation\n',
#  'n00164801\tcall\n',
#  'n00164999\tco-option, co-optation\n',
#  'n00165178\tdelegacy\n',
#  'n00165298\tordination, ordinance\n',
#  'n00165563\trecognition\n',
#  'n00165793\tlaying on of hands\n',
#  'n00165942\tmove\n',
#  'n00166172\tmove\n',
#  'n00166355\tchess move\n',
#  'n00166552\tcastle, castling\n',
#  'n00166702\tcapture\n',
#  'n00166865\ten passant\n',
#  'n00167063\texchange\n',
#  'n00167278\texchange\n',
#  'n00167446\tcheck\n',
#  'n00167580\tdiscovered check\n',
#  'n00167764\tcheckmate, mate\n',
#  'n00167950\tgambit\n',
#  'n00168121\tdemarche\n',
#  'n00168237\tmaneuver, manoeuvre, tactical maneuver, tactical manoeuvre\n',
#  'n00168505\tparking\n',
#  'n00168658\tmove, relocation\n',
#  'n00168911\tflit\n',
#  'n00169047\tdownshift\n',
#  'n00169147\tdownshift\n',
#  'n00169305\tbank\n',
#  'n00169522\tvertical bank\n',
#  'n00169651\tchandelle\n',
#  'n00169811\tloop, loop-the-loop\n',
#  'n00170005\tinside loop\n',
#  'n00170172\toutside loop\n',
#  'n00170340\troll\n',
#  'n00170536\tbarrel roll\n',
#  'n00170643\tsnap roll\n',
#  'n00170710\tslip, sideslip\n',
#  'n00170844\tflight maneuver, airplane maneuver\n',
#  'n00171050\tstraight-arm\n',
#  'n00171249\tdevice, gimmick, twist\n',
#  'n00171507\tmnemonic\n',
#  'n00171618\ttrick, fast one\n',
#  'n00171882\tshtik, schtik, shtick, schtick\n',
#  'n00172073\tfeint\n',
#  'n00172217\tjuke, fake\n',
#  'n00172347\tfootwork\n',
#  'n00172490\tploy, gambit, stratagem\n',
#  'n00172598\truse, artifice\n',
#  'n00172710\tmeans, agency, way\n',
#  'n00173172\tdint\n',
#  'n00173283\tescape\n',
#  'n00173487\tfast track\n',
#  'n00173761\tinstrument, tool\n',
#  'n00174003\troad\n',
#  'n00174127\troyal road\n',
#  'n00174260\tstepping stone\n',
#  'n00174412\tmeasure, step\n',
#  'n00174663\tcountermeasure\n',
#  'n00174782\tbear hug\n',
#  'n00174950\tproxy fight\n',
#  'n00175174\tleveraged buyout\n',
#  'n00175433\tbust-up takeover\n',
#  'n00175605\tshark repellent, porcupine provision\n',
#  'n00175875\tgolden parachute\n',
#  'n00176052\tgreenmail\n',
#  'n00176312\tpac-man strategy\n',
#  'n00176449\tpoison pill\n',
#  'n00176609\tsuicide pill\n',
#  'n00176766\tsafe harbor\n',
#  'n00176994\tscorched-earth policy\n',
#  'n00177127\tdiagnostic procedure, diagnostic technique\n',
#  'n00177448\texpedient\n',
#  'n00177638\tbackstop\n',
#  'n00177783\temergency procedure\n',
#  'n00178024\texperimental procedure\n',
#  'n00178177\tdouble-blind procedure, double-blind experiment, double-blind study\n',
#  'n00178551\tmakeshift, stopgap, make-do\n',
#  'n00178700\tcrutch\n',
#  'n00178832\timprovisation, temporary expedient\n',
#  'n00178972\tpis aller, last resort\n',
#  'n00179125\tdesperate measure\n',
#  'n00179275\topen sesame\n',
#  'n00179380\tsalvation\n',
#  'n00179576\ttooth\n',
#  'n00179683\tvoice\n',
#  'n00179916\twings\n',
#  'n00180054\tcasting lots, drawing lots, sortition\n',
#  'n00180228\tresolution\n',
#  'n00180413\tadoption, acceptance, acceptation, espousal\n',
#  'n00180770\tembrace, bosom\n',
#  'n00180962\telection\n',
#  'n00181191\tco-option, co-optation\n',
#  'n00181373\treelection\n',
#  'n00181495\tplebiscite\n',
#  'n00181640\treferendum\n',
#  'n00181781\telection\n',
#  'n00182213\tvote\n',
#  'n00182435\tgeneral election\n',
#  'n00182571\tprimary, primary election\n',
#  'n00182723\tdirect primary\n',
#  'n00182897\tclosed primary\n',
#  'n00183084\topen primary\n',
#  'n00183240\tby-election, bye-election\n',
#  'n00183357\trunoff\n',
#  'n00183505\tvote, ballot, voting, balloting\n',
#  'n00183995\tblock vote\n',
#  'n00184135\tcumulative vote\n',
#  'n00184362\tsecret ballot\n',
#  'n00184501\tsplit ticket\n',
#  'n00184652\tstraight ticket\n',
#  'n00184802\tmultiple voting\n',
#  'n00184981\tcasting vote\n',
#  'n00185104\treconciliation, balancing\n',
#  'n00185307\tequation, equating\n',
#  'n00185438\tbreech delivery, breech birth, breech presentation\n',
#  'n00185612\tfrank breech, frank breech delivery\n',
#  'n00185778\tcesarean delivery, caesarean delivery, caesarian delivery, cesarean section, cesarian section, caesarean section, caesarian section, C-section, cesarean, cesarian, caesarean, caesarian, abdominal delivery\n',
#  'n00186251\tforceps delivery\n',
#  'n00186549\tmidwifery\n',
#  'n00186634\tscore\n',
#  'n00187056\tbowling score\n',
#  "n00187144\tbull's eye\n",
#  'n00187337\tgoal\n',
#  'n00187499\town goal\n',
#  'n00187710\tstrike, ten-strike\n',
#  'n00187890\tspare\n',
#  'n00188007\topen frame, break\n',
#  'n00188183\taudible\n',
#  'n00188341\tfootball score\n',
#  'n00188449\ttouchback\n',
#  'n00188620\tsafety\n',
#  'n00188766\ttouchdown\n',
#  'n00188934\tfield goal\n',
#  'n00189106\tconversion\n',
#  'n00189257\tpoint after, point after touchdown, extra point\n',
#  'n00189476\tbaseball score\n',
#  'n00189565\trun, tally\n',
#  'n00189896\tearned run\n',
#  'n00190040\tunearned run\n',
#  'n00190180\trun batted in, rbi\n',
#  'n00190338\tbasketball score\n',
#  'n00190431\tbasket, field goal\n',
#  'n00190579\that trick\n',
#  'n00190783\tsolution\n',
#  'n00190931\tRussian roulette\n',
#  'n00191142\tchange\n',
#  'n00191980\tfiltration\n',
#  'n00192149\tpercolation\n',
#  'n00192300\treduction, simplification\n',
#  'n00192457\tschematization, schematisation\n',
#  'n00192613\teconomy, saving\n',
#  'n00192910\tretrenchment, curtailment, downsizing\n',
#  'n00193099\teconomy of scale\n',
#  'n00193225\taccommodation\n',
#  'n00193406\tadaptation\n',
#  'n00193622\tdark adaptation\n',
#  'n00193811\tlight adaptation\n',
#  'n00194005\ttake-up\n',
#  'n00194127\treadjustment\n',
#  'n00194257\tdomestication\n',
#  'n00194414\tdecimalization, decimalisation\n',
#  'n00194645\tmetrification, metrication\n',
#  'n00194831\thabituation\n',
#  'n00194969\tvariation, variance\n',
#  'n00195194\tvariation\n',
#  'n00195415\tturning\n',
#  'n00195569\tdiversification, variegation\n',
#  'n00195938\tflux\n',
#  'n00196084\tswitch, switching, shift\n',
#  'n00196402\tswitcheroo\n',
#  'n00196485\tsubstitution, exchange, commutation\n',
#  'n00196848\tnovation\n',
#  'n00197136\tpitching change\n',
#  'n00197229\tsuperannuation\n',
#  'n00197419\tsupersedure, supersession\n',
#  'n00197610\tsupplanting, displacement\n',
#  'n00197772\treplacement, replacing\n',
#  'n00198118\tsubrogation\n',
#  'n00198270\tweaning, ablactation\n',
#  'n00198451\tpromotion\n',
#  'n00198631\tpreferment\n',
#  'n00198793\tdemotion\n',
#  'n00198919\tinvestment, investiture\n',
#  'n00199130\tchange of state\n',
#  'n00199707\talteration, modification, adjustment\n',
#  'n00200041\tdistraction, misdirection\n',
#  'n00200244\taeration\n',
#  'n00200379\tmodulation\n',
#  'n00200563\tqualification\n',
#  'n00200768\treorganization\n',
#  'n00201058\tpassage, transition\n',
#  'n00201269\tfossilization, fossilisation\n',
#  'n00201397\tsegue\n',
#  'n00201516\tmeddling, tampering\n',
#  'n00201671\ttransfer, transference\n',
#  'n00201923\tprohibition, inhibition, forbiddance\n',
#  'n00202284\tresistance, opposition\n',
#  'n00202620\tlockout\n',
#  'n00202816\treaction\n',
#  'n00203020\tbacklash\n',
#  'n00203208\twhitelash, white backlash\n',
#  'n00203342\trejection\n',
#  'n00203649\tbrush-off\n',
#  'n00203753\tavoidance, turning away, shunning, dodging\n',
#  'n00204022\taversion, averting\n',
#  'n00204199\tescape\n',
#  'n00204334\tnear thing\n',
#  'n00204439\tabandonment, forsaking, desertion\n',
#  'n00204659\texposure\n',
#  'n00204814\tapostasy, tergiversation\n',
#  'n00204943\tbolt\n',
#  'n00205079\trenunciation, forgoing, forswearing\n',
#  'n00205349\tnonacceptance, turndown\n',
#  'n00205543\tforsaking, giving up\n',
#  'n00205649\tabnegation, self-abnegation, denial, self-denial, self-renunciation\n',
#  'n00205891\tforfeit, forfeiture, sacrifice\n',
#  'n00206130\tboycott\n',
#  'n00206302\tbanishment, proscription\n',
#  'n00206600\tanathematization, anathematisation\n',
#  'n00206779\tdisbarment\n',
#  'n00206927\tejection, exclusion, expulsion, riddance\n',
#  'n00207306\tdeportation\n',
#  'n00207434\tostracism\n',
#  'n00207622\tbarring, blackball\n',
#  'n00207761\texile, deportation, expatriation, transportation\n',
#  'n00208141\tBabylonian Captivity\n',
#  'n00208277\texcommunication, excision\n',
#  'n00208521\trelegation\n',
#  'n00208694\trustication\n',
#  'n00208797\touster, ousting\n',
#  'n00208943\tdeposition, dethronement\n',
#  'n00209132\tsuspension, temporary removal\n',
#  'n00209301\trustication\n',
#  'n00209446\tdisplacement\n',
#  'n00209546\tveto\n',
#  'n00209680\tpocket veto\n',
#  'n00209789\twrite-in\n',
#  'n00209943\ttermination, ending, conclusion\n',
#  'n00210518\tfinish, finishing\n',
#  'n00210797\tfinale, close, closing curtain, finis\n',
#  'n00210940\trelease, tone ending\n',
#  'n00211110\tcompletion, culmination, closing, windup, mop up\n',
#  'n00211462\tfinalization, finalisation\n',
#  'n00211593\tfollow-through\n',
#  'n00211776\tfollow-through\n',
#  'n00212065\tgraduation\n',
#  'n00212205\tretirement\n',
#  'n00212377\thibernation\n',
#  'n00212551\trustication\n',
#  'n00212678\tswan song, last hurrah\n',
#  'n00212808\trelinquishment, relinquishing\n',
#  'n00213052\tcession, ceding\n',
#  'n00213186\thandover\n',
#  'n00213343\tsurrender\n',
#  'n00213482\textradition\n',
#  'n00213694\trelease, waiver, discharge\n',
#  'n00213903\texemption, immunity, granting immunity\n',
#  'n00214148\tfix\n',
#  'n00214315\tofficial immunity\n',
#  'n00214526\tsovereign immunity\n',
#  'n00214794\ttransactional immunity\n',
#  'n00215013\tuse immunity, testimonial immunity\n',
#  'n00215314\tdissolution, breakup\n',
#  'n00215534\tsplitsville\n',
#  'n00215683\toverthrow\n',
#  'n00215838\tsubversion, subversive activity\n',
#  'n00216038\tadjournment, dissolution\n',
#  'n00216174\tdismissal, dismission, discharge, firing, liberation, release, sack, sacking\n',
#  'n00216607\tconge, congee\n',
#  'n00216723\tremoval\n',
#  'n00216834\tpurge\n',
#  'n00217014\tdestruction, devastation\n',
#  ...]

# %%
class_label = {}
for item in class_value:
    key = item.split("\t")[0]
    value = item.split("\t")[1][:-1]
    class_label[key] = value

# %%
plt.imshow(next(dataset.as_numpy_iterator())[0][0].astype(np.uint8))
plt.title(class_label[class_name[next(dataset.as_numpy_iterator())[1][0]]])
# Out:
# Text(0.5, 1.0, 'goldfish, Carassius auratus')

# %%
next(dataset.as_numpy_iterator())[1][0]
# Out:
# 5

# %%
class_label[class_name[np.argmax(loaded_model.predict(np.expand_dims(next(dataset.as_numpy_iterator())[0][0],axis=0)))]]
# Out:
# 1/1 [==============================] - 5s 5s/step
# 'bullfrog, Rana catesbeiana'

# %% [markdown]
# ## Multiple Prediction

# %%
images_to_predict = next(dataset.as_numpy_iterator())

# %%
class_label[class_name[labels[1]]][]
# Out:
# 'koala, koala bear, kangaroo bear, native bear, Phascolarctos cinereus'

# %%
plt.figure(figsize=(10, 10))
images, labels = images_to_predict
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.imshow(images[i].astype("uint8"))
    plt.title("{}-{} \n {} - {}".format("R",class_label[class_name[labels[i]]][:20],"P",))
    # plt.title("{}-{}".format()
    plt.axis("off")

# %%
model_predictions = loaded_model.predict(images)
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
model_predicted_labels = [class_label[class_name[np.argmax(prediction)]] for prediction in model_predictions]

# %%
model_predicted_labels
# Out:
# ['centipede',
#  'koala, koala bear, kangaroo bear, native bear, Phascolarctos cinereus',
#  'sea slug, nudibranch',
#  'black widow, Latrodectus mactans',
#  'brain coral',
#  'slug',
#  'snail',
#  'black widow, Latrodectus mactans',
#  'jellyfish',
#  'boa constrictor, Constrictor constrictor',
#  'centipede',
#  'tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui',
#  'American lobster, Northern lobster, Maine lobster, Homarus americanus',
#  'tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui',
#  'centipede',
#  'boa constrictor, Constrictor constrictor']
